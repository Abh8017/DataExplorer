# %% [markdown]
# <a href="https://colab.research.google.com/github/Abh8017/DataExplorer/blob/master/GitHub_data_Collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #This python program will help us in getting the data from GitHub and we can use that data to

# %%
pip install request
# Out:
# Requirement already satisfied: request in /usr/local/lib/python3.6/dist-packages (2019.4.13)
# Requirement already satisfied: get in /usr/local/lib/python3.6/dist-packages (from request) (2019.4.13)
# Requirement already satisfied: post in /usr/local/lib/python3.6/dist-packages (from request) (2019.4.13)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from request) (46.1.3)
# Requirement already satisfied: query-string in /usr/local/lib/python3.6/dist-packages (from get->request) (2019.4.13)
# Requirement already satisfied: public in /usr/local/lib/python3.6/dist-packages (from query-string->get->request) (2019.4.13)

# %%
import json
import requests
import numpy as np
import pandas as pd

import requests
from requests.auth import HTTPBasicAuth

# %% [markdown]
# #We will fetch the credentials from the .JSON file to create an authentication variable

# %%
credentials = json.loads(open('/content/drive/My Drive/GitHub: Data-Collection & Insights/credentials.json').read())
authentication = HTTPBasicAuth(credentials['username'], credentials['password'])

# %% [markdown]
# #Now we can extract the basic user information from this like
#
#
# 1. Name
# 2. Email
# 3. Location
# 4. Public repos
# 5. Public gists
# 6. About
#
# This inforamtion is just for the users not for the repositories

# %%
data = requests.get('https://api.github.com/users/' + credentials['username'],
                    auth = authentication)
data = data.json()
data
# Out:
# {'avatar_url': 'https://avatars3.githubusercontent.com/u/38239830?v=4',
#  'bio': None,
#  'blog': '',
#  'collaborators': 0,
#  'company': '@intelligaia ',
#  'created_at': '2018-04-10T06:26:36Z',
#  'disk_usage': 133,
#  'email': None,
#  'events_url': 'https://api.github.com/users/Abh8017/events{/privacy}',
#  'followers': 0,
#  'followers_url': 'https://api.github.com/users/Abh8017/followers',
#  'following': 1,
#  'following_url': 'https://api.github.com/users/Abh8017/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/Abh8017/gists{/gist_id}',
#  'gravatar_id': '',
#  'hireable': None,
#  'html_url': 'https://github.com/Abh8017',
#  'id': 38239830,
#  'location': 'India',
#  'login': 'Abh8017',
#  'name': None,
#  'node_id': 'MDQ6VXNlcjM4MjM5ODMw',
#  'organizations_url': 'https://api.github.com/users/Abh8017/orgs',
#  'owned_private_repos': 0,
#  'plan': {'collaborators': 0,
#   'name': 'free',
#   'private_repos': 10000,
#   'space': 976562499},
#  'private_gists': 1,
#  'public_gists': 0,
#  'public_repos': 6,
#  'received_events_url': 'https://api.github.com/users/Abh8017/received_events',
#  'repos_url': 'https://api.github.com/users/Abh8017/repos',
#  'site_admin': False,
#  'starred_url': 'https://api.github.com/users/Abh8017/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/Abh8017/subscriptions',
#  'total_private_repos': 0,
#  'two_factor_authentication': False,
#  'type': 'User',
#  'updated_at': '2020-04-12T12:51:51Z',
#  'url': 'https://api.github.com/users/Abh8017'}

# %%
print("Information about user {}:\n".format(credentials['username']))
print("Name: {}".format(data['name']))
print("Email: {}".format(data['email']))
print("Location: {}".format(data['location']))
print("Public repos: {}".format(data['public_repos']))
print("Public gists: {}".format(data['public_gists']))
print("About: {}".format(data['bio']))
# Out:
# Information about user Abh8017:
#
# Name: None
# Email: None
# Location: India
# Public repos: 6
# Public gists: 0
# About: None

# %% [markdown]
# # Now we will extract information about the Repositories
#
# Default number of repositories is 30, we can iterate the api for as much as we want

# %%
url = data['repos_url']
page_no = 1
repos_data = []
while (True):
    response = requests.get(url, auth = authentication)
    response = response.json()
    repos_data = repos_data + response
    repos_fetched = len(response)
    print("Total repositories fetched: {}".format(repos_fetched))
    if (repos_fetched == 30):
        page_no = page_no + 1
        url = data['repos_url'].encode("UTF-8") + '?page=' + str(page_no)
    else:
        break
# Out:
# Total repositories fetched: 6

# %% [markdown]
# #First I will explore the data for only one repository so that I can check the data points that what we can use for our data exploration
#
#
#
# > The data I am fetching for the repo goes by the name of **"Awesome-datascience"**

# %%
repos_data[0]
# Out:
# {'archive_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/{archive_format}{/ref}',
#  'archived': False,
#  'assignees_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/assignees{/user}',
#  'blobs_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/blobs{/sha}',
#  'branches_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/branches{/branch}',
#  'clone_url': 'https://github.com/Abh8017/awesome-datascience.git',
#  'collaborators_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/collaborators{/collaborator}',
#  'comments_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/comments{/number}',
#  'commits_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits{/sha}',
#  'compare_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/compare/{base}...{head}',
#  'contents_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/contents/{+path}',
#  'contributors_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/contributors',
#  'created_at': '2018-12-13T06:30:17Z',
#  'default_branch': 'master',
#  'deployments_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/deployments',
#  'description': ':memo: An awesome Data Science repository to learn and apply for real world problems.',
#  'disabled': False,
#  'downloads_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/downloads',
#  'events_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/events',
#  'fork': True,
#  'forks': 0,
#  'forks_count': 0,
#  'forks_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/forks',
#  'full_name': 'Abh8017/awesome-datascience',
#  'git_commits_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/commits{/sha}',
#  'git_refs_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/refs{/sha}',
#  'git_tags_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/tags{/sha}',
#  'git_url': 'git://github.com/Abh8017/awesome-datascience.git',
#  'has_downloads': True,
#  'has_issues': False,
#  'has_pages': False,
#  'has_projects': True,
#  'has_wiki': True,
#  'homepage': '',
#  'hooks_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/hooks',
#  'html_url': 'https://github.com/Abh8017/awesome-datascience',
#  'id': 161594269,
#  'issue_comment_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/issues/comments{/number}',
#  'issue_events_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/issues/events{/number}',
#  'issues_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/issues{/number}',
#  'keys_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/keys{/key_id}',
#  'labels_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/labels{/name}',
#  'language': None,
#  'languages_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/languages',
#  'license': {'key': 'mit',
#   'name': 'MIT License',
#   'node_id': 'MDc6TGljZW5zZTEz',
#   'spdx_id': 'MIT',
#   'url': 'https://api.github.com/licenses/mit'},
#  'merges_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/merges',
#  'milestones_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/milestones{/number}',
#  'mirror_url': None,
#  'name': 'awesome-datascience',
#  'node_id': 'MDEwOlJlcG9zaXRvcnkxNjE1OTQyNjk=',
#  'notifications_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/notifications{?since,all,participating}',
#  'open_issues': 0,
#  'open_issues_count': 0,
#  'owner': {'avatar_url': 'https://avatars3.githubusercontent.com/u/38239830?v=4',
#   'events_url': 'https://api.github.com/users/Abh8017/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/Abh8017/followers',
#   'following_url': 'https://api.github.com/users/Abh8017/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Abh8017/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/Abh8017',
#   'id': 38239830,
#   'login': 'Abh8017',
#   'node_id': 'MDQ6VXNlcjM4MjM5ODMw',
#   'organizations_url': 'https://api.github.com/users/Abh8017/orgs',
#   'received_events_url': 'https://api.github.com/users/Abh8017/received_events',
#   'repos_url': 'https://api.github.com/users/Abh8017/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/Abh8017/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Abh8017/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/Abh8017'},
#  'permissions': {'admin': True, 'pull': True, 'push': True},
#  'private': False,
#  'pulls_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/pulls{/number}',
#  'pushed_at': '2018-11-26T22:50:39Z',
#  'releases_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/releases{/id}',
#  'size': 561,
#  'ssh_url': 'git@github.com:Abh8017/awesome-datascience.git',
#  'stargazers_count': 0,
#  'stargazers_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/stargazers',
#  'statuses_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/statuses/{sha}',
#  'subscribers_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/subscribers',
#  'subscription_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/subscription',
#  'svn_url': 'https://github.com/Abh8017/awesome-datascience',
#  'tags_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/tags',
#  'teams_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/teams',
#  'trees_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/trees{/sha}',
#  'updated_at': '2019-08-06T13:48:17Z',
#  'url': 'https://api.github.com/repos/Abh8017/awesome-datascience',
#  'watchers': 0,
#  'watchers_count': 0}

# %% [markdown]
# From above code we can get a number of datapoints , which comes out 56 data points in all. I selected few of the
#
# 1. id: Unique id for the repository.
# 2. name: The name of the repository.
# 3. description: The description of the repository.
# 4. created_at: The time and date when the repository was first created.
# 5. updated_at: The time and date when the repository was last updated.
# 6. login: Username of the owner of the repository.
# 7. license: The license type (if any).
# 7. has_wiki: A boolean that signifies if the repository has a wiki document.
# 8. forks_count: Total forks of the repository.
# 9. open_issues_count: Total issues opened in the repository.
# 10. stargazers_count: The total stars on the reepository.
# 11. watchers_count: Total users watching the repository.
#
# ---
# **I'll pick some other points for further analysis**
#
# 1. url: The url of the repository.
# 2. commits_url: The url for all commits in the repository.
# 3. languages_url: The url for all languages in the repository. for e.g. Angular, HTML and JS
# ***The commit url, I'll remove the end value inside the braces.***

# %%
repos_information = []
for i, repo in enumerate(repos_data):
    data = []
    data.append(repo['id'])
    data.append(repo['name'])
    data.append(repo['description'])
    data.append(repo['created_at'])
    data.append(repo['updated_at'])
    data.append(repo['owner']['login'])
    data.append(repo['license']['name'] if repo['license'] != None else None)
    data.append(repo['has_wiki'])
    data.append(repo['forks_count'])
    data.append(repo['open_issues_count'])
    data.append(repo['stargazers_count'])
    data.append(repo['watchers_count'])
    data.append(repo['url'])
    data.append(repo['commits_url'].split("{")[0])
    data.append(repo['url'] + '/languages')
    repos_information.append(data)

# %% [markdown]
# # Now we'll transform the data in a more readable format i.e. in tabular format

# %%
repos_df = pd.DataFrame(repos_information, columns = ['Id', 'Name', 'Description', 'Created on', 'Updated on', 
                                                      'Owner', 'License', 'Includes wiki', 'Forks count', 
                                                      'Issues count', 'Stars count', 'Watchers count',
                                                      'Repo URL', 'Commits URL', 'Languages URL'])
repos_df.head(10)
# Out:
#           Id  ...                                      Languages URL
# 0  161594269  ...  https://api.github.com/repos/Abh8017/awesome-d...
# 1  180587058  ...  https://api.github.com/repos/Abh8017/DataExplo...
# 2  135285043  ...  https://api.github.com/repos/Abh8017/DataViz_R...
# 3  254913611  ...  https://api.github.com/repos/Abh8017/GitHub-Us...
# 4  201095153  ...  https://api.github.com/repos/Abh8017/jupyter_c...
# 5  208550814  ...  https://api.github.com/repos/Abh8017/student-p...
#
# [6 rows x 15 columns]

# %% [markdown]
# # Now we'll fetch the data related to programming laguages used in each repositories and then we can analyse the data related to the languages which are dominating our Git Repos

# %%
for i in range(repos_df.shape[0]):
    response = requests.get(repos_df.loc[i, 'Languages URL'], auth = authentication)
    response = response.json()
    print(i, response)
    if response != {}:
        languages = []
        for key, value in response.items():
            languages.append(key)
        languages = ', '.join(languages)
        repos_df.loc[i, 'Languages'] = languages
    else:
        repos_df.loc[i, 'Languages'] = ""
# Out:
# 0 {}
# 1 {'R': 95122}
# 2 {}
# 3 {'Jupyter Notebook': 263810, 'Python': 4021}
# 4 {'Jupyter Notebook': 146459}
# 5 {'Python': 3554}

# %% [markdown]
# # After getting all the data, we now extract the data in a CSV for both Repo_df and languages

# %%
repos_df.to_csv('repos_info.csv', index = False)

# %% [markdown]
# # Now I will look for the data related to the commits done till now in a CSV format

# %%
response = requests.get(repos_df.loc[0, 'Commits URL'], auth = authentication)
response.json()
# Out:
# [{'author': {'avatar_url': 'https://avatars2.githubusercontent.com/u/4239092?v=4',
#    'events_url': 'https://api.github.com/users/erolrecep/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/erolrecep/followers',
#    'following_url': 'https://api.github.com/users/erolrecep/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/erolrecep/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/erolrecep',
#    'id': 4239092,
#    'login': 'erolrecep',
#    'node_id': 'MDQ6VXNlcjQyMzkwOTI=',
#    'organizations_url': 'https://api.github.com/users/erolrecep/orgs',
#    'received_events_url': 'https://api.github.com/users/erolrecep/received_events',
#    'repos_url': 'https://api.github.com/users/erolrecep/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/erolrecep/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/erolrecep/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/erolrecep'},
#   'comments_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/8db8b0d92d3afe92e56a0856a7ed71b7cd6a8fde/comments',
#   'commit': {'author': {'date': '2018-11-26T22:50:39Z',
#     'email': 'recep.90@gmail.com',
#     'name': 'Recep'},
#    'comment_count': 0,
#    'committer': {'date': '2018-11-26T22:50:39Z',
#     'email': 'noreply@github.com',
#     'name': 'GitHub'},
#    'message': 'Merge pull request #141 from asavinov/master\n\nAdd Lambdo to Toolboxes',
#    'tree': {'sha': '09bbc87ba7e32a7e31ffd69eb45b878e85965dfe',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/trees/09bbc87ba7e32a7e31ffd69eb45b878e85965dfe'},
#    'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/commits/8db8b0d92d3afe92e56a0856a7ed71b7cd6a8fde',
#    'verification': {'payload': 'tree 09bbc87ba7e32a7e31ffd69eb45b878e85965dfe\nparent 87e3ed4a6d881a7c547a58d3b06e33dd1e0cf23d\nparent 4aad64cdd5cc5ba4059cbc448ef9072938c01eff\nauthor Recep <recep.90@gmail.com> 1543272639 -0600\ncommitter GitHub <noreply@github.com> 1543272639 -0600\n\nMerge pull request #141 from asavinov/master\n\nAdd Lambdo to Toolboxes',
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n=VG87\n-----END PGP SIGNATURE-----\n',
#     'verified': True}},
#   'committer': {'avatar_url': 'https://avatars3.githubusercontent.com/u/19864447?v=4',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/web-flow',
#    'id': 19864447,
#    'login': 'web-flow',
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/web-flow'},
#   'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/8db8b0d92d3afe92e56a0856a7ed71b7cd6a8fde',
#   'node_id': 'MDY6Q29tbWl0MTYxNTk0MjY5OjhkYjhiMGQ5MmQzYWZlOTJlNTZhMDg1NmE3ZWQ3MWI3Y2Q2YThmZGU=',
#   'parents': [{'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/87e3ed4a6d881a7c547a58d3b06e33dd1e0cf23d',
#     'sha': '87e3ed4a6d881a7c547a58d3b06e33dd1e0cf23d',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/87e3ed4a6d881a7c547a58d3b06e33dd1e0cf23d'},
#    {'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/4aad64cdd5cc5ba4059cbc448ef9072938c01eff',
#     'sha': '4aad64cdd5cc5ba4059cbc448ef9072938c01eff',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/4aad64cdd5cc5ba4059cbc448ef9072938c01eff'}],
#   'sha': '8db8b0d92d3afe92e56a0856a7ed71b7cd6a8fde',
#   'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/8db8b0d92d3afe92e56a0856a7ed71b7cd6a8fde'},
#  {'author': {'avatar_url': 'https://avatars2.githubusercontent.com/u/4239092?v=4',
#    'events_url': 'https://api.github.com/users/erolrecep/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/erolrecep/followers',
#    'following_url': 'https://api.github.com/users/erolrecep/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/erolrecep/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/erolrecep',
#    'id': 4239092,
#    'login': 'erolrecep',
#    'node_id': 'MDQ6VXNlcjQyMzkwOTI=',
#    'organizations_url': 'https://api.github.com/users/erolrecep/orgs',
#    'received_events_url': 'https://api.github.com/users/erolrecep/received_events',
#    'repos_url': 'https://api.github.com/users/erolrecep/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/erolrecep/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/erolrecep/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/erolrecep'},
#   'comments_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/87e3ed4a6d881a7c547a58d3b06e33dd1e0cf23d/comments',
#   'commit': {'author': {'date': '2018-11-26T22:50:09Z',
#     'email': 'recep.90@gmail.com',
#     'name': 'Recep'},
#    'comment_count': 0,
#    'committer': {'date': '2018-11-26T22:50:09Z',
#     'email': 'noreply@github.com',
#     'name': 'GitHub'},
#    'message': 'Merge pull request #137 from roziunicorn/master\n\nAdded Data Science at Scale with Python and Dask',
#    'tree': {'sha': 'a519249446127c42a0f81759d55c151442c4d6a1',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/trees/a519249446127c42a0f81759d55c151442c4d6a1'},
#    'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/commits/87e3ed4a6d881a7c547a58d3b06e33dd1e0cf23d',
#    'verification': {'payload': 'tree a519249446127c42a0f81759d55c151442c4d6a1\nparent 509ae948a123c88a3dbcf2153f9a609bac610add\nparent 2fa0b00ae9e499fdfdeb5ed990587d7d7fe4fb94\nauthor Recep <recep.90@gmail.com> 1543272609 -0600\ncommitter GitHub <noreply@github.com> 1543272609 -0600\n\nMerge pull request #137 from roziunicorn/master\n\nAdded Data Science at Scale with Python and Dask',
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n=/zc+\n-----END PGP SIGNATURE-----\n',
#     'verified': True}},
#   'committer': {'avatar_url': 'https://avatars3.githubusercontent.com/u/19864447?v=4',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/web-flow',
#    'id': 19864447,
#    'login': 'web-flow',
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/web-flow'},
#   'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/87e3ed4a6d881a7c547a58d3b06e33dd1e0cf23d',
#   'node_id': 'MDY6Q29tbWl0MTYxNTk0MjY5Ojg3ZTNlZDRhNmQ4ODFhN2M1NDdhNThkM2IwNmUzM2RkMWUwY2YyM2Q=',
#   'parents': [{'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/509ae948a123c88a3dbcf2153f9a609bac610add',
#     'sha': '509ae948a123c88a3dbcf2153f9a609bac610add',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/509ae948a123c88a3dbcf2153f9a609bac610add'},
#    {'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/2fa0b00ae9e499fdfdeb5ed990587d7d7fe4fb94',
#     'sha': '2fa0b00ae9e499fdfdeb5ed990587d7d7fe4fb94',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/2fa0b00ae9e499fdfdeb5ed990587d7d7fe4fb94'}],
#   'sha': '87e3ed4a6d881a7c547a58d3b06e33dd1e0cf23d',
#   'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/87e3ed4a6d881a7c547a58d3b06e33dd1e0cf23d'},
#  {'author': {'avatar_url': 'https://avatars0.githubusercontent.com/u/1926849?v=4',
#    'events_url': 'https://api.github.com/users/asavinov/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/asavinov/followers',
#    'following_url': 'https://api.github.com/users/asavinov/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/asavinov/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/asavinov',
#    'id': 1926849,
#    'login': 'asavinov',
#    'node_id': 'MDQ6VXNlcjE5MjY4NDk=',
#    'organizations_url': 'https://api.github.com/users/asavinov/orgs',
#    'received_events_url': 'https://api.github.com/users/asavinov/received_events',
#    'repos_url': 'https://api.github.com/users/asavinov/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/asavinov/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/asavinov/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/asavinov'},
#   'comments_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/4aad64cdd5cc5ba4059cbc448ef9072938c01eff/comments',
#   'commit': {'author': {'date': '2018-11-26T19:22:00Z',
#     'email': 'savinov@conceptoriented.org',
#     'name': 'Alexandr Savinov'},
#    'comment_count': 0,
#    'committer': {'date': '2018-11-26T19:22:00Z',
#     'email': 'savinov@conceptoriented.org',
#     'name': 'Alexandr Savinov'},
#    'message': 'Add Lambdo to Toolboxes',
#    'tree': {'sha': 'f3bd6e413b5a0b92185037365bbd1e8000569f69',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/trees/f3bd6e413b5a0b92185037365bbd1e8000569f69'},
#    'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/commits/4aad64cdd5cc5ba4059cbc448ef9072938c01eff',
#    'verification': {'payload': None,
#     'reason': 'unsigned',
#     'signature': None,
#     'verified': False}},
#   'committer': {'avatar_url': 'https://avatars0.githubusercontent.com/u/1926849?v=4',
#    'events_url': 'https://api.github.com/users/asavinov/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/asavinov/followers',
#    'following_url': 'https://api.github.com/users/asavinov/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/asavinov/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/asavinov',
#    'id': 1926849,
#    'login': 'asavinov',
#    'node_id': 'MDQ6VXNlcjE5MjY4NDk=',
#    'organizations_url': 'https://api.github.com/users/asavinov/orgs',
#    'received_events_url': 'https://api.github.com/users/asavinov/received_events',
#    'repos_url': 'https://api.github.com/users/asavinov/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/asavinov/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/asavinov/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/asavinov'},
#   'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/4aad64cdd5cc5ba4059cbc448ef9072938c01eff',
#   'node_id': 'MDY6Q29tbWl0MTYxNTk0MjY5OjRhYWQ2NGNkZDVjYzViYTQwNTljYmM0NDhlZjkwNzI5MzhjMDFlZmY=',
#   'parents': [{'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/509ae948a123c88a3dbcf2153f9a609bac610add',
#     'sha': '509ae948a123c88a3dbcf2153f9a609bac610add',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/509ae948a123c88a3dbcf2153f9a609bac610add'}],
#   'sha': '4aad64cdd5cc5ba4059cbc448ef9072938c01eff',
#   'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/4aad64cdd5cc5ba4059cbc448ef9072938c01eff'},
#  {'author': None,
#   'comments_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/509ae948a123c88a3dbcf2153f9a609bac610add/comments',
#   'commit': {'author': {'date': '2018-11-01T21:37:02Z',
#     'email': 'huseyin.mert@bulutyazilim.com',
#     'name': 'Hüseyin Mert'},
#    'comment_count': 0,
#    'committer': {'date': '2018-11-01T21:37:02Z',
#     'email': 'noreply@github.com',
#     'name': 'GitHub'},
#    'message': 'Merge pull request #139 from Polovinkin/add-ms-data-science\n\nAdded good Microsoft Data Science program',
#    'tree': {'sha': 'd8629879b2250941850562de879ffaf7cfbb3b60',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/trees/d8629879b2250941850562de879ffaf7cfbb3b60'},
#    'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/commits/509ae948a123c88a3dbcf2153f9a609bac610add',
#    'verification': {'payload': 'tree d8629879b2250941850562de879ffaf7cfbb3b60\nparent 53bcae496a60cd0792e74db366440c0455201197\nparent 6ace8c937ed3dd377847b335da40f2160cf986af\nauthor Hüseyin Mert <huseyin.mert@bulutyazilim.com> 1541108222 +0300\ncommitter GitHub <noreply@github.com> 1541108222 +0300\n\nMerge pull request #139 from Polovinkin/add-ms-data-science\n\nAdded good Microsoft Data Science program',
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n=VJZ7\n-----END PGP SIGNATURE-----\n',
#     'verified': True}},
#   'committer': {'avatar_url': 'https://avatars3.githubusercontent.com/u/19864447?v=4',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/web-flow',
#    'id': 19864447,
#    'login': 'web-flow',
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/web-flow'},
#   'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/509ae948a123c88a3dbcf2153f9a609bac610add',
#   'node_id': 'MDY6Q29tbWl0MTYxNTk0MjY5OjUwOWFlOTQ4YTEyM2M4OGEzZGJjZjIxNTNmOWE2MDliYWM2MTBhZGQ=',
#   'parents': [{'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/53bcae496a60cd0792e74db366440c0455201197',
#     'sha': '53bcae496a60cd0792e74db366440c0455201197',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/53bcae496a60cd0792e74db366440c0455201197'},
#    {'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/6ace8c937ed3dd377847b335da40f2160cf986af',
#     'sha': '6ace8c937ed3dd377847b335da40f2160cf986af',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/6ace8c937ed3dd377847b335da40f2160cf986af'}],
#   'sha': '509ae948a123c88a3dbcf2153f9a609bac610add',
#   'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/509ae948a123c88a3dbcf2153f9a609bac610add'},
#  {'author': None,
#   'comments_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/53bcae496a60cd0792e74db366440c0455201197/comments',
#   'commit': {'author': {'date': '2018-11-01T21:35:57Z',
#     'email': 'huseyin.mert@bulutyazilim.com',
#     'name': 'Hüseyin Mert'},
#    'comment_count': 0,
#    'committer': {'date': '2018-11-01T21:35:57Z',
#     'email': 'noreply@github.com',
#     'name': 'GitHub'},
#    'message': "Merge pull request #138 from ethanchewy/patch-1\n\nAdded Chris Albon's website as a Data Science Resource",
#    'tree': {'sha': '393a9c2701f446b97556508475241a0224e6479c',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/trees/393a9c2701f446b97556508475241a0224e6479c'},
#    'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/commits/53bcae496a60cd0792e74db366440c0455201197',
#    'verification': {'payload': "tree 393a9c2701f446b97556508475241a0224e6479c\nparent c3c7878fcc051aa929ec66a7090f07a0baec734a\nparent 25cb66233d94d2b396706696919a1ff08d35aae4\nauthor Hüseyin Mert <huseyin.mert@bulutyazilim.com> 1541108157 +0300\ncommitter GitHub <noreply@github.com> 1541108157 +0300\n\nMerge pull request #138 from ethanchewy/patch-1\n\nAdded Chris Albon's website as a Data Science Resource",
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n=eeaK\n-----END PGP SIGNATURE-----\n',
#     'verified': True}},
#   'committer': {'avatar_url': 'https://avatars3.githubusercontent.com/u/19864447?v=4',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/web-flow',
#    'id': 19864447,
#    'login': 'web-flow',
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/web-flow'},
#   'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/53bcae496a60cd0792e74db366440c0455201197',
#   'node_id': 'MDY6Q29tbWl0MTYxNTk0MjY5OjUzYmNhZTQ5NmE2MGNkMDc5MmU3NGRiMzY2NDQwYzA0NTUyMDExOTc=',
#   'parents': [{'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/c3c7878fcc051aa929ec66a7090f07a0baec734a',
#     'sha': 'c3c7878fcc051aa929ec66a7090f07a0baec734a',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/c3c7878fcc051aa929ec66a7090f07a0baec734a'},
#    {'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/25cb66233d94d2b396706696919a1ff08d35aae4',
#     'sha': '25cb66233d94d2b396706696919a1ff08d35aae4',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/25cb66233d94d2b396706696919a1ff08d35aae4'}],
#   'sha': '53bcae496a60cd0792e74db366440c0455201197',
#   'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/53bcae496a60cd0792e74db366440c0455201197'},
#  {'author': {'avatar_url': 'https://avatars0.githubusercontent.com/u/26386168?v=4',
#    'events_url': 'https://api.github.com/users/Polovinkin/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/Polovinkin/followers',
#    'following_url': 'https://api.github.com/users/Polovinkin/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Polovinkin/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/Polovinkin',
#    'id': 26386168,
#    'login': 'Polovinkin',
#    'node_id': 'MDQ6VXNlcjI2Mzg2MTY4',
#    'organizations_url': 'https://api.github.com/users/Polovinkin/orgs',
#    'received_events_url': 'https://api.github.com/users/Polovinkin/received_events',
#    'repos_url': 'https://api.github.com/users/Polovinkin/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/Polovinkin/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Polovinkin/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/Polovinkin'},
#   'comments_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/6ace8c937ed3dd377847b335da40f2160cf986af/comments',
#   'commit': {'author': {'date': '2018-10-29T08:07:28Z',
#     'email': 'dtpolovinkin@gmail.com',
#     'name': 'Dmitry'},
#    'comment_count': 0,
#    'committer': {'date': '2018-10-29T08:07:28Z',
#     'email': 'dtpolovinkin@gmail.com',
#     'name': 'Dmitry'},
#    'message': 'Added good Microsoft Data Science program',
#    'tree': {'sha': '9ea1fe04aab80d56f75337b5f1f9b8a620fc607c',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/trees/9ea1fe04aab80d56f75337b5f1f9b8a620fc607c'},
#    'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/commits/6ace8c937ed3dd377847b335da40f2160cf986af',
#    'verification': {'payload': None,
#     'reason': 'unsigned',
#     'signature': None,
#     'verified': False}},
#   'committer': {'avatar_url': 'https://avatars0.githubusercontent.com/u/26386168?v=4',
#    'events_url': 'https://api.github.com/users/Polovinkin/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/Polovinkin/followers',
#    'following_url': 'https://api.github.com/users/Polovinkin/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Polovinkin/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/Polovinkin',
#    'id': 26386168,
#    'login': 'Polovinkin',
#    'node_id': 'MDQ6VXNlcjI2Mzg2MTY4',
#    'organizations_url': 'https://api.github.com/users/Polovinkin/orgs',
#    'received_events_url': 'https://api.github.com/users/Polovinkin/received_events',
#    'repos_url': 'https://api.github.com/users/Polovinkin/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/Polovinkin/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Polovinkin/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/Polovinkin'},
#   'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/6ace8c937ed3dd377847b335da40f2160cf986af',
#   'node_id': 'MDY6Q29tbWl0MTYxNTk0MjY5OjZhY2U4YzkzN2VkM2RkMzc3ODQ3YjMzNWRhNDBmMjE2MGNmOTg2YWY=',
#   'parents': [{'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/c3c7878fcc051aa929ec66a7090f07a0baec734a',
#     'sha': 'c3c7878fcc051aa929ec66a7090f07a0baec734a',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/c3c7878fcc051aa929ec66a7090f07a0baec734a'}],
#   'sha': '6ace8c937ed3dd377847b335da40f2160cf986af',
#   'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/6ace8c937ed3dd377847b335da40f2160cf986af'},
#  {'author': {'avatar_url': 'https://avatars3.githubusercontent.com/u/8660827?v=4',
#    'events_url': 'https://api.github.com/users/ethanchewy/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/ethanchewy/followers',
#    'following_url': 'https://api.github.com/users/ethanchewy/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ethanchewy/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/ethanchewy',
#    'id': 8660827,
#    'login': 'ethanchewy',
#    'node_id': 'MDQ6VXNlcjg2NjA4Mjc=',
#    'organizations_url': 'https://api.github.com/users/ethanchewy/orgs',
#    'received_events_url': 'https://api.github.com/users/ethanchewy/received_events',
#    'repos_url': 'https://api.github.com/users/ethanchewy/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/ethanchewy/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ethanchewy/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/ethanchewy'},
#   'comments_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/25cb66233d94d2b396706696919a1ff08d35aae4/comments',
#   'commit': {'author': {'date': '2018-10-29T05:28:46Z',
#     'email': '17chiue@gmail.com',
#     'name': 'Ethan Chiu'},
#    'comment_count': 0,
#    'committer': {'date': '2018-10-29T05:28:46Z',
#     'email': 'noreply@github.com',
#     'name': 'GitHub'},
#    'message': 'Added data science resource',
#    'tree': {'sha': '393a9c2701f446b97556508475241a0224e6479c',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/trees/393a9c2701f446b97556508475241a0224e6479c'},
#    'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/commits/25cb66233d94d2b396706696919a1ff08d35aae4',
#    'verification': {'payload': 'tree 393a9c2701f446b97556508475241a0224e6479c\nparent c3c7878fcc051aa929ec66a7090f07a0baec734a\nauthor Ethan Chiu <17chiue@gmail.com> 1540790926 -0700\ncommitter GitHub <noreply@github.com> 1540790926 -0700\n\nAdded data science resource',
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n=k5xR\n-----END PGP SIGNATURE-----\n',
#     'verified': True}},
#   'committer': {'avatar_url': 'https://avatars3.githubusercontent.com/u/19864447?v=4',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/web-flow',
#    'id': 19864447,
#    'login': 'web-flow',
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/web-flow'},
#   'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/25cb66233d94d2b396706696919a1ff08d35aae4',
#   'node_id': 'MDY6Q29tbWl0MTYxNTk0MjY5OjI1Y2I2NjIzM2Q5NGQyYjM5NjcwNjY5NjkxOWExZmYwOGQzNWFhZTQ=',
#   'parents': [{'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/c3c7878fcc051aa929ec66a7090f07a0baec734a',
#     'sha': 'c3c7878fcc051aa929ec66a7090f07a0baec734a',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/c3c7878fcc051aa929ec66a7090f07a0baec734a'}],
#   'sha': '25cb66233d94d2b396706696919a1ff08d35aae4',
#   'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/25cb66233d94d2b396706696919a1ff08d35aae4'},
#  {'author': {'avatar_url': 'https://avatars3.githubusercontent.com/u/43975706?v=4',
#    'events_url': 'https://api.github.com/users/roziunicorn/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/roziunicorn/followers',
#    'following_url': 'https://api.github.com/users/roziunicorn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/roziunicorn/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/roziunicorn',
#    'id': 43975706,
#    'login': 'roziunicorn',
#    'node_id': 'MDQ6VXNlcjQzOTc1NzA2',
#    'organizations_url': 'https://api.github.com/users/roziunicorn/orgs',
#    'received_events_url': 'https://api.github.com/users/roziunicorn/received_events',
#    'repos_url': 'https://api.github.com/users/roziunicorn/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/roziunicorn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/roziunicorn/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/roziunicorn'},
#   'comments_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/2fa0b00ae9e499fdfdeb5ed990587d7d7fe4fb94/comments',
#   'commit': {'author': {'date': '2018-10-29T01:39:35Z',
#     'email': '43975706+roziunicorn@users.noreply.github.com',
#     'name': 'roziunicorn'},
#    'comment_count': 0,
#    'committer': {'date': '2018-10-29T01:39:35Z',
#     'email': 'noreply@github.com',
#     'name': 'GitHub'},
#    'message': 'Added Data Science at Scale with Python and Dask\n\nin Books',
#    'tree': {'sha': '953482686a49077d9bf4f52c57253af6eacb9738',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/trees/953482686a49077d9bf4f52c57253af6eacb9738'},
#    'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/commits/2fa0b00ae9e499fdfdeb5ed990587d7d7fe4fb94',
#    'verification': {'payload': 'tree 953482686a49077d9bf4f52c57253af6eacb9738\nparent c3c7878fcc051aa929ec66a7090f07a0baec734a\nauthor roziunicorn <43975706+roziunicorn@users.noreply.github.com> 1540777175 -0400\ncommitter GitHub <noreply@github.com> 1540777175 -0400\n\nAdded Data Science at Scale with Python and Dask\n\nin Books',
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n=jQ8t\n-----END PGP SIGNATURE-----\n',
#     'verified': True}},
#   'committer': {'avatar_url': 'https://avatars3.githubusercontent.com/u/19864447?v=4',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/web-flow',
#    'id': 19864447,
#    'login': 'web-flow',
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/web-flow'},
#   'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/2fa0b00ae9e499fdfdeb5ed990587d7d7fe4fb94',
#   'node_id': 'MDY6Q29tbWl0MTYxNTk0MjY5OjJmYTBiMDBhZTllNDk5ZmRmZGViNWVkOTkwNTg3ZDdkN2ZlNGZiOTQ=',
#   'parents': [{'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/c3c7878fcc051aa929ec66a7090f07a0baec734a',
#     'sha': 'c3c7878fcc051aa929ec66a7090f07a0baec734a',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/c3c7878fcc051aa929ec66a7090f07a0baec734a'}],
#   'sha': '2fa0b00ae9e499fdfdeb5ed990587d7d7fe4fb94',
#   'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/2fa0b00ae9e499fdfdeb5ed990587d7d7fe4fb94'},
#  {'author': None,
#   'comments_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/c3c7878fcc051aa929ec66a7090f07a0baec734a/comments',
#   'commit': {'author': {'date': '2018-10-22T01:26:33Z',
#     'email': 'huseyin.mert@bulutyazilim.com',
#     'name': 'Hüseyin Mert'},
#    'comment_count': 0,
#    'committer': {'date': '2018-10-22T01:26:33Z',
#     'email': 'noreply@github.com',
#     'name': 'GitHub'},
#    'message': 'Merge pull request #136 from benedekrozemberczki/patch-1\n\nAdded two specialised ML awesome aggregators.',
#    'tree': {'sha': '76bcba72edf2d917f63c3c2eb015f68c323ceca3',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/trees/76bcba72edf2d917f63c3c2eb015f68c323ceca3'},
#    'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/commits/c3c7878fcc051aa929ec66a7090f07a0baec734a',
#    'verification': {'payload': 'tree 76bcba72edf2d917f63c3c2eb015f68c323ceca3\nparent 919898f441bd2d8a0553f0b2ff2c93fca9fdd5e8\nparent 70779526feb5f1f49e754457c23515c35be94b35\nauthor Hüseyin Mert <huseyin.mert@bulutyazilim.com> 1540171593 +0300\ncommitter GitHub <noreply@github.com> 1540171593 +0300\n\nMerge pull request #136 from benedekrozemberczki/patch-1\n\nAdded two specialised ML awesome aggregators.',
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n=i35Y\n-----END PGP SIGNATURE-----\n',
#     'verified': True}},
#   'committer': {'avatar_url': 'https://avatars3.githubusercontent.com/u/19864447?v=4',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/web-flow',
#    'id': 19864447,
#    'login': 'web-flow',
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/web-flow'},
#   'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/c3c7878fcc051aa929ec66a7090f07a0baec734a',
#   'node_id': 'MDY6Q29tbWl0MTYxNTk0MjY5OmMzYzc4NzhmY2MwNTFhYTkyOWVjNjZhNzA5MGYwN2EwYmFlYzczNGE=',
#   'parents': [{'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/919898f441bd2d8a0553f0b2ff2c93fca9fdd5e8',
#     'sha': '919898f441bd2d8a0553f0b2ff2c93fca9fdd5e8',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/919898f441bd2d8a0553f0b2ff2c93fca9fdd5e8'},
#    {'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/70779526feb5f1f49e754457c23515c35be94b35',
#     'sha': '70779526feb5f1f49e754457c23515c35be94b35',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/70779526feb5f1f49e754457c23515c35be94b35'}],
#   'sha': 'c3c7878fcc051aa929ec66a7090f07a0baec734a',
#   'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/c3c7878fcc051aa929ec66a7090f07a0baec734a'},
#  {'author': {'avatar_url': 'https://avatars1.githubusercontent.com/u/17380887?v=4',
#    'events_url': 'https://api.github.com/users/benedekrozemberczki/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/benedekrozemberczki/followers',
#    'following_url': 'https://api.github.com/users/benedekrozemberczki/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/benedekrozemberczki/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/benedekrozemberczki',
#    'id': 17380887,
#    'login': 'benedekrozemberczki',
#    'node_id': 'MDQ6VXNlcjE3MzgwODg3',
#    'organizations_url': 'https://api.github.com/users/benedekrozemberczki/orgs',
#    'received_events_url': 'https://api.github.com/users/benedekrozemberczki/received_events',
#    'repos_url': 'https://api.github.com/users/benedekrozemberczki/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/benedekrozemberczki/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/benedekrozemberczki/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/benedekrozemberczki'},
#   'comments_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/70779526feb5f1f49e754457c23515c35be94b35/comments',
#   'commit': {'author': {'date': '2018-10-21T15:01:17Z',
#     'email': 'benedek.rozemberczki@gmail.com',
#     'name': 'Do You Even Cross-Validate?'},
#    'comment_count': 0,
#    'committer': {'date': '2018-10-21T15:01:17Z',
#     'email': 'noreply@github.com',
#     'name': 'GitHub'},
#    'message': 'Added two specialised ML awesome aggregators.',
#    'tree': {'sha': '76bcba72edf2d917f63c3c2eb015f68c323ceca3',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/trees/76bcba72edf2d917f63c3c2eb015f68c323ceca3'},
#    'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/commits/70779526feb5f1f49e754457c23515c35be94b35',
#    'verification': {'payload': 'tree 76bcba72edf2d917f63c3c2eb015f68c323ceca3\nparent 919898f441bd2d8a0553f0b2ff2c93fca9fdd5e8\nauthor Do You Even Cross-Validate? <benedek.rozemberczki@gmail.com> 1540134077 +0100\ncommitter GitHub <noreply@github.com> 1540134077 +0100\n\nAdded two specialised ML awesome aggregators.',
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n=mvAx\n-----END PGP SIGNATURE-----\n',
#     'verified': True}},
#   'committer': {'avatar_url': 'https://avatars3.githubusercontent.com/u/19864447?v=4',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/web-flow',
#    'id': 19864447,
#    'login': 'web-flow',
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/web-flow'},
#   'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/70779526feb5f1f49e754457c23515c35be94b35',
#   'node_id': 'MDY6Q29tbWl0MTYxNTk0MjY5OjcwNzc5NTI2ZmViNWYxZjQ5ZTc1NDQ1N2MyMzUxNWMzNWJlOTRiMzU=',
#   'parents': [{'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/919898f441bd2d8a0553f0b2ff2c93fca9fdd5e8',
#     'sha': '919898f441bd2d8a0553f0b2ff2c93fca9fdd5e8',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/919898f441bd2d8a0553f0b2ff2c93fca9fdd5e8'}],
#   'sha': '70779526feb5f1f49e754457c23515c35be94b35',
#   'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/70779526feb5f1f49e754457c23515c35be94b35'},
#  {'author': None,
#   'comments_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/919898f441bd2d8a0553f0b2ff2c93fca9fdd5e8/comments',
#   'commit': {'author': {'date': '2018-09-12T09:35:52Z',
#     'email': 'huseyin.mert@bulutyazilim.com',
#     'name': 'Hüseyin Mert'},
#    'comment_count': 0,
#    'committer': {'date': '2018-09-12T09:35:52Z',
#     'email': 'noreply@github.com',
#     'name': 'GitHub'},
#    'message': 'Merge pull request #135 from faizankshaikh/master\n\nCorrecting link to DataHack Platform',
#    'tree': {'sha': '079bf71a51a80e0ee3cee6e3065cee365290b179',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/trees/079bf71a51a80e0ee3cee6e3065cee365290b179'},
#    'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/commits/919898f441bd2d8a0553f0b2ff2c93fca9fdd5e8',
#    'verification': {'payload': 'tree 079bf71a51a80e0ee3cee6e3065cee365290b179\nparent c09e5cdf16000a71f87fea4ee6556fc21e31f541\nparent fd9ac0467b798502540304896bb3bfaecb3e1385\nauthor Hüseyin Mert <huseyin.mert@bulutyazilim.com> 1536744952 +0300\ncommitter GitHub <noreply@github.com> 1536744952 +0300\n\nMerge pull request #135 from faizankshaikh/master\n\nCorrecting link to DataHack Platform',
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n=5oID\n-----END PGP SIGNATURE-----\n',
#     'verified': True}},
#   'committer': {'avatar_url': 'https://avatars3.githubusercontent.com/u/19864447?v=4',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/web-flow',
#    'id': 19864447,
#    'login': 'web-flow',
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/web-flow'},
#   'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/919898f441bd2d8a0553f0b2ff2c93fca9fdd5e8',
#   'node_id': 'MDY6Q29tbWl0MTYxNTk0MjY5OjkxOTg5OGY0NDFiZDJkOGEwNTUzZjBiMmZmMmM5M2ZjYTlmZGQ1ZTg=',
#   'parents': [{'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/c09e5cdf16000a71f87fea4ee6556fc21e31f541',
#     'sha': 'c09e5cdf16000a71f87fea4ee6556fc21e31f541',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/c09e5cdf16000a71f87fea4ee6556fc21e31f541'},
#    {'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/fd9ac0467b798502540304896bb3bfaecb3e1385',
#     'sha': 'fd9ac0467b798502540304896bb3bfaecb3e1385',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/fd9ac0467b798502540304896bb3bfaecb3e1385'}],
#   'sha': '919898f441bd2d8a0553f0b2ff2c93fca9fdd5e8',
#   'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/919898f441bd2d8a0553f0b2ff2c93fca9fdd5e8'},
#  {'author': {'avatar_url': 'https://avatars0.githubusercontent.com/u/8406903?v=4',
#    'events_url': 'https://api.github.com/users/faizankshaikh/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/faizankshaikh/followers',
#    'following_url': 'https://api.github.com/users/faizankshaikh/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/faizankshaikh/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/faizankshaikh',
#    'id': 8406903,
#    'login': 'faizankshaikh',
#    'node_id': 'MDQ6VXNlcjg0MDY5MDM=',
#    'organizations_url': 'https://api.github.com/users/faizankshaikh/orgs',
#    'received_events_url': 'https://api.github.com/users/faizankshaikh/received_events',
#    'repos_url': 'https://api.github.com/users/faizankshaikh/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/faizankshaikh/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/faizankshaikh/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/faizankshaikh'},
#   'comments_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/fd9ac0467b798502540304896bb3bfaecb3e1385/comments',
#   'commit': {'author': {'date': '2018-09-12T07:12:33Z',
#     'email': 'faizankshaikh@gmail.com',
#     'name': 'jalFaizy'},
#    'comment_count': 0,
#    'committer': {'date': '2018-09-12T07:12:33Z',
#     'email': 'noreply@github.com',
#     'name': 'GitHub'},
#    'message': 'Update README.md',
#    'tree': {'sha': '079bf71a51a80e0ee3cee6e3065cee365290b179',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/trees/079bf71a51a80e0ee3cee6e3065cee365290b179'},
#    'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/commits/fd9ac0467b798502540304896bb3bfaecb3e1385',
#    'verification': {'payload': 'tree 079bf71a51a80e0ee3cee6e3065cee365290b179\nparent c09e5cdf16000a71f87fea4ee6556fc21e31f541\nauthor jalFaizy <faizankshaikh@gmail.com> 1536736353 +0530\ncommitter GitHub <noreply@github.com> 1536736353 +0530\n\nUpdate README.md',
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n=e/zq\n-----END PGP SIGNATURE-----\n',
#     'verified': True}},
#   'committer': {'avatar_url': 'https://avatars3.githubusercontent.com/u/19864447?v=4',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/web-flow',
#    'id': 19864447,
#    'login': 'web-flow',
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
# ...
#   'parents': [{'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/a91d22b69f39df54e7a5ba7d85078760ac1b14d0',
#     'sha': 'a91d22b69f39df54e7a5ba7d85078760ac1b14d0',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/a91d22b69f39df54e7a5ba7d85078760ac1b14d0'}],
#   'sha': 'e18d59cf5691a0c1bb07842d8b265ce20f575bbd',
#   'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/e18d59cf5691a0c1bb07842d8b265ce20f575bbd'},
#  {'author': None,
#   'comments_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/a91d22b69f39df54e7a5ba7d85078760ac1b14d0/comments',
#   'commit': {'author': {'date': '2018-07-25T14:16:54Z',
#     'email': 'huseyin.mert@bulutyazilim.com',
#     'name': 'Hüseyin Mert'},
#    'comment_count': 0,
#    'committer': {'date': '2018-07-25T14:16:54Z',
#     'email': 'noreply@github.com',
#     'name': 'GitHub'},
#    'message': 'Merge pull request #126 from knightcube/patch-1\n\nAdded Open Government Datasets Platform India link',
#    'tree': {'sha': '0afe451a76f83076f06a2d4e5c8f9b94ed133560',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/trees/0afe451a76f83076f06a2d4e5c8f9b94ed133560'},
#    'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/commits/a91d22b69f39df54e7a5ba7d85078760ac1b14d0',
#    'verification': {'payload': 'tree 0afe451a76f83076f06a2d4e5c8f9b94ed133560\nparent 8cd385bf6155ad6511100701658237b11cce03fc\nparent 906babd856cf1b2fbdde1bafc8f37dbc4989d437\nauthor Hüseyin Mert <huseyin.mert@bulutyazilim.com> 1532528214 +0300\ncommitter GitHub <noreply@github.com> 1532528214 +0300\n\nMerge pull request #126 from knightcube/patch-1\n\nAdded Open Government Datasets Platform India link',
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n=6nTS\n-----END PGP SIGNATURE-----\n',
#     'verified': True}},
#   'committer': {'avatar_url': 'https://avatars3.githubusercontent.com/u/19864447?v=4',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/web-flow',
#    'id': 19864447,
#    'login': 'web-flow',
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/web-flow'},
#   'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/a91d22b69f39df54e7a5ba7d85078760ac1b14d0',
#   'node_id': 'MDY6Q29tbWl0MTYxNTk0MjY5OmE5MWQyMmI2OWYzOWRmNTRlN2E1YmE3ZDg1MDc4NzYwYWMxYjE0ZDA=',
#   'parents': [{'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/8cd385bf6155ad6511100701658237b11cce03fc',
#     'sha': '8cd385bf6155ad6511100701658237b11cce03fc',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/8cd385bf6155ad6511100701658237b11cce03fc'},
#    {'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/906babd856cf1b2fbdde1bafc8f37dbc4989d437',
#     'sha': '906babd856cf1b2fbdde1bafc8f37dbc4989d437',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/906babd856cf1b2fbdde1bafc8f37dbc4989d437'}],
#   'sha': 'a91d22b69f39df54e7a5ba7d85078760ac1b14d0',
#   'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/a91d22b69f39df54e7a5ba7d85078760ac1b14d0'},
#  {'author': {'avatar_url': 'https://avatars3.githubusercontent.com/u/22871961?v=4',
#    'events_url': 'https://api.github.com/users/knightcube/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/knightcube/followers',
#    'following_url': 'https://api.github.com/users/knightcube/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/knightcube/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/knightcube',
#    'id': 22871961,
#    'login': 'knightcube',
#    'node_id': 'MDQ6VXNlcjIyODcxOTYx',
#    'organizations_url': 'https://api.github.com/users/knightcube/orgs',
#    'received_events_url': 'https://api.github.com/users/knightcube/received_events',
#    'repos_url': 'https://api.github.com/users/knightcube/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/knightcube/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/knightcube/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/knightcube'},
#   'comments_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/906babd856cf1b2fbdde1bafc8f37dbc4989d437/comments',
#   'commit': {'author': {'date': '2018-07-25T13:28:48Z',
#     'email': 'rajatcube@gmail.com',
#     'name': 'Rajat Kumar Gupta'},
#    'comment_count': 0,
#    'committer': {'date': '2018-07-25T13:28:48Z',
#     'email': 'noreply@github.com',
#     'name': 'GitHub'},
#    'message': 'Added Open Government Datasets Platform India link',
#    'tree': {'sha': '0afe451a76f83076f06a2d4e5c8f9b94ed133560',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/trees/0afe451a76f83076f06a2d4e5c8f9b94ed133560'},
#    'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/commits/906babd856cf1b2fbdde1bafc8f37dbc4989d437',
#    'verification': {'payload': 'tree 0afe451a76f83076f06a2d4e5c8f9b94ed133560\nparent 8cd385bf6155ad6511100701658237b11cce03fc\nauthor Rajat Kumar Gupta <rajatcube@gmail.com> 1532525328 +0530\ncommitter GitHub <noreply@github.com> 1532525328 +0530\n\nAdded Open Government Datasets Platform India link',
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n=fXJv\n-----END PGP SIGNATURE-----\n',
#     'verified': True}},
#   'committer': {'avatar_url': 'https://avatars3.githubusercontent.com/u/19864447?v=4',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/web-flow',
#    'id': 19864447,
#    'login': 'web-flow',
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/web-flow'},
#   'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/906babd856cf1b2fbdde1bafc8f37dbc4989d437',
#   'node_id': 'MDY6Q29tbWl0MTYxNTk0MjY5OjkwNmJhYmQ4NTZjZjFiMmZiZGRlMWJhZmM4ZjM3ZGJjNDk4OWQ0Mzc=',
#   'parents': [{'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/8cd385bf6155ad6511100701658237b11cce03fc',
#     'sha': '8cd385bf6155ad6511100701658237b11cce03fc',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/8cd385bf6155ad6511100701658237b11cce03fc'}],
#   'sha': '906babd856cf1b2fbdde1bafc8f37dbc4989d437',
#   'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/906babd856cf1b2fbdde1bafc8f37dbc4989d437'},
#  {'author': None,
#   'comments_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/8cd385bf6155ad6511100701658237b11cce03fc/comments',
#   'commit': {'author': {'date': '2018-07-14T11:37:47Z',
#     'email': 'huseyin.mert@bulutyazilim.com',
#     'name': 'Hüseyin Mert'},
#    'comment_count': 0,
#    'committer': {'date': '2018-07-14T11:37:47Z',
#     'email': 'noreply@github.com',
#     'name': 'GitHub'},
#    'message': 'Merge pull request #125 from Teoretic6/Teoretic6/ms-research-open-data\n\nAdded "Microsoft Research Open Data" datasets link',
#    'tree': {'sha': '7aebb32fb28ec179578afc5fa02c060ba2fad4f9',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/trees/7aebb32fb28ec179578afc5fa02c060ba2fad4f9'},
#    'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/commits/8cd385bf6155ad6511100701658237b11cce03fc',
#    'verification': {'payload': 'tree 7aebb32fb28ec179578afc5fa02c060ba2fad4f9\nparent 0c26162fc506094d331f9dc452ed18d88474d9ab\nparent ea5d1d366e8a37d67de3c7d77e4da50f0719270d\nauthor Hüseyin Mert <huseyin.mert@bulutyazilim.com> 1531568267 +0300\ncommitter GitHub <noreply@github.com> 1531568267 +0300\n\nMerge pull request #125 from Teoretic6/Teoretic6/ms-research-open-data\n\nAdded "Microsoft Research Open Data" datasets link',
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n=Qkie\n-----END PGP SIGNATURE-----\n',
#     'verified': True}},
#   'committer': {'avatar_url': 'https://avatars3.githubusercontent.com/u/19864447?v=4',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/web-flow',
#    'id': 19864447,
#    'login': 'web-flow',
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/web-flow'},
#   'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/8cd385bf6155ad6511100701658237b11cce03fc',
#   'node_id': 'MDY6Q29tbWl0MTYxNTk0MjY5OjhjZDM4NWJmNjE1NWFkNjUxMTEwMDcwMTY1ODIzN2IxMWNjZTAzZmM=',
#   'parents': [{'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/0c26162fc506094d331f9dc452ed18d88474d9ab',
#     'sha': '0c26162fc506094d331f9dc452ed18d88474d9ab',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/0c26162fc506094d331f9dc452ed18d88474d9ab'},
#    {'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/ea5d1d366e8a37d67de3c7d77e4da50f0719270d',
#     'sha': 'ea5d1d366e8a37d67de3c7d77e4da50f0719270d',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/ea5d1d366e8a37d67de3c7d77e4da50f0719270d'}],
#   'sha': '8cd385bf6155ad6511100701658237b11cce03fc',
#   'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/8cd385bf6155ad6511100701658237b11cce03fc'},
#  {'author': {'avatar_url': 'https://avatars0.githubusercontent.com/u/9078134?v=4',
#    'events_url': 'https://api.github.com/users/Teoretic6/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/Teoretic6/followers',
#    'following_url': 'https://api.github.com/users/Teoretic6/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Teoretic6/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/Teoretic6',
#    'id': 9078134,
#    'login': 'Teoretic6',
#    'node_id': 'MDQ6VXNlcjkwNzgxMzQ=',
#    'organizations_url': 'https://api.github.com/users/Teoretic6/orgs',
#    'received_events_url': 'https://api.github.com/users/Teoretic6/received_events',
#    'repos_url': 'https://api.github.com/users/Teoretic6/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/Teoretic6/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Teoretic6/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/Teoretic6'},
#   'comments_url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/ea5d1d366e8a37d67de3c7d77e4da50f0719270d/comments',
#   'commit': {'author': {'date': '2018-07-14T11:34:41Z',
#     'email': 'teoretic6@mail.ru',
#     'name': 'Teoretic6'},
#    'comment_count': 0,
#    'committer': {'date': '2018-07-14T11:34:41Z',
#     'email': 'teoretic6@mail.ru',
#     'name': 'Teoretic6'},
#    'message': 'Added "Microsoft Research Open Data" datasets link',
#    'tree': {'sha': '7aebb32fb28ec179578afc5fa02c060ba2fad4f9',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/trees/7aebb32fb28ec179578afc5fa02c060ba2fad4f9'},
#    'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/git/commits/ea5d1d366e8a37d67de3c7d77e4da50f0719270d',
#    'verification': {'payload': None,
#     'reason': 'unsigned',
#     'signature': None,
#     'verified': False}},
#   'committer': {'avatar_url': 'https://avatars0.githubusercontent.com/u/9078134?v=4',
#    'events_url': 'https://api.github.com/users/Teoretic6/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/Teoretic6/followers',
#    'following_url': 'https://api.github.com/users/Teoretic6/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Teoretic6/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/Teoretic6',
#    'id': 9078134,
#    'login': 'Teoretic6',
#    'node_id': 'MDQ6VXNlcjkwNzgxMzQ=',
#    'organizations_url': 'https://api.github.com/users/Teoretic6/orgs',
#    'received_events_url': 'https://api.github.com/users/Teoretic6/received_events',
#    'repos_url': 'https://api.github.com/users/Teoretic6/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/Teoretic6/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Teoretic6/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/Teoretic6'},
#   'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/ea5d1d366e8a37d67de3c7d77e4da50f0719270d',
#   'node_id': 'MDY6Q29tbWl0MTYxNTk0MjY5OmVhNWQxZDM2NmU4YTM3ZDY3ZGUzYzdkNzdlNGRhNTBmMDcxOTI3MGQ=',
#   'parents': [{'html_url': 'https://github.com/Abh8017/awesome-datascience/commit/0c26162fc506094d331f9dc452ed18d88474d9ab',
#     'sha': '0c26162fc506094d331f9dc452ed18d88474d9ab',
#     'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/0c26162fc506094d331f9dc452ed18d88474d9ab'}],
#   'sha': 'ea5d1d366e8a37d67de3c7d77e4da50f0719270d',
#   'url': 'https://api.github.com/repos/Abh8017/awesome-datascience/commits/ea5d1d366e8a37d67de3c7d77e4da50f0719270d'}]

# %% [markdown]
# # Not everything is important to us, so to narrow down the search result I'll filter them on the basis of time , date and messages

# %%
commits_information = []
for i in range(repos_df.shape[0]):
    url = repos_df.loc[i, 'Commits URL']
    page_no = 1
    while (True):
        response = requests.get(url, auth = authentication)
        response = response.json()
        print("URL: {}, commits: {}".format(url, len(response)))
        for commit in response:
            commit_data = []
            commit_data.append(repos_df.loc[i, 'Id'])
            commit_data.append(commit['sha'])
            commit_data.append(commit['commit']['committer']['date'])
            commit_data.append(commit['commit']['message'])
            commits_information.append(commit_data)
        if (len(response) == 100):
            page_no = page_no + 1
            url = repos_df.loc[i, 'Commits URL'] + '?page=' + str(page_no)
        else:
            break
# Out:
# URL: https://api.github.com/repos/Abh8017/awesome-datascience/commits, commits: 30
# URL: https://api.github.com/repos/Abh8017/DataExplorer/commits, commits: 30
# URL: https://api.github.com/repos/Abh8017/DataViz_R/commits, commits: 1
# URL: https://api.github.com/repos/Abh8017/GitHub-User-Insights-using-API/commits, commits: 12
# URL: https://api.github.com/repos/Abh8017/jupyter_colab/commits, commits: 4
# URL: https://api.github.com/repos/Abh8017/student-performance-prediction/commits, commits: 23

# %% [markdown]
# #Now same with this, we'll extract the data related to commits done on each repo in a CSV format

# %%
commits_df = pd.DataFrame(commits_information, columns = ['Repo Id', 'Commit Id', 'Date', 'Message'])
commits_df.head(5)
# Out:
#      Repo Id  ...                                            Message
# 0  161594269  ...  Merge pull request #141 from asavinov/master\n...
# 1  161594269  ...  Merge pull request #137 from roziunicorn/maste...
# 2  161594269  ...                            Add Lambdo to Toolboxes
# 3  161594269  ...  Merge pull request #139 from Polovinkin/add-ms...
# 4  161594269  ...  Merge pull request #138 from ethanchewy/patch-...
#
# [5 rows x 4 columns]

# %%
commits_df.to_csv('commits_info.csv', index = False)
